# %%
#coding:utf-8
import pandas as pd

# %%
import pandas as pd
pd.options.display.max_columns = 200
pd.options.mode.chained_assignment = None

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from string import punctuation

from collections import Counter
import re
import numpy as np

# %%
#读取训练数据
columns = ["name","url","price","vip_price","comment","shop_name","shipping"]
data = pd.read_csv("peijian.csv")
data.columns = columns

# %%
data.dtypes
# Out:
# name          object
# url           object
# price        float64
# vip_price     object
# comment       object
# shop_name     object
# shipping      object
# dtype: object

# %%
print(data.shape)
# Out:
# (118, 7)

# %%
data[:2]
# Out:
#                                                 name  \
# 0  【818手机节搭配推荐:亿色华为P30Pro无边钻石膜】【专享第2件半价，贴坏包赔！】原配定...
# 1  【自营精选】华为P30PRO双面玻璃全包防摔保护，万磁王磁吸保护壳》》\n推荐华为P30Pr...
#
#                                      url  price vip_price comment  \
# 0  https://item.jd.com/100003940246.html   39.0    ￥34.59     5万+
# 1  https://item.jd.com/100003961571.html   99.0    ￥95.00   1800+
#
#             shop_name                      shipping
# 0          ESR京东自营旗舰店  '自营''放心购''券2880-300''满88-20'
# 1  斯泰克（STIGER）京东自营旗舰店       '自营''券2880-300''满88-20'

# %%
data.comment = data.comment.str.replace("+","")
comlist = []
for index,item in pd.DataFrame(data).iterrows():
    comment = item["comment"]
    try:
        temp = int(comment)
        comlist.append(temp)
        continue
    except:
        temp = comment.split("万")
        comlist.append(float(temp[0])*10000)

# %%
data.comment = pd.DataFrame(comlist)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
comment_menan = data.comment.describe()["mean"]

# %%
nicedata = data[data["comment"]>comment_menan]

# %%
nicedata.price.describe()
# Out:
# count     29.000000
# mean      50.289655
# std       50.360716
# min       14.900000
# 25%       29.000000
# 50%       38.000000
# 75%       56.000000
# max      298.000000
# Name: price, dtype: float64

# %%
# %matplotlib inline
nicedata.shop_name.value_counts(normalize=True).plot(kind='bar', grid=True, figsize=(16, 9))

# %%
data = data.drop_duplicates('name')
data = data[~data['name'].isnull()]

print(data.shape)
# Out:
# (68, 7)

# %%
data = data[(data.name.map(len) > 5) & (data.name.map(len) <= 300)]
data.reset_index(inplace=True, drop=True)

print(data.shape)
# Out:
# (67, 7)

# %%
data.name.map(len).hist(figsize=(15, 5), bins=100)

# %%
# 创建停用词list
def stopwordslist(filepath):
    stopwords = [line.strip() for line in open(filepath, 'r').readlines()]
    return stopwords

# 对句子进行分词
def seg_sentence(sentence):
    sentence_seged = jieba.cut(sentence)
    stopwords = stopwordslist('./stopwords/哈工大停用词表.txt')  # 这里加载停用词的路径
    outstr = ''
    for word in sentence_seged:
        if word not in stopwords:
            if word != '\t':
                outstr += word
                outstr += " "
    return outstr

# %%
import jieba

# %%
# 预处理单个词
def preprocess_word(word):
    # 去掉标点
    word = word.strip('\'"?!,.():;？！，。…“”（）：；<>《》/ 、rn【】[]|~#%&*br')
    # 去掉 - &
    word = re.sub(r'(-|\')', '', word)
    return word

# 预处理句子
def preprocess_sentence(sentence, stop_words=False):
    sentence = sentence.lower()
    # 转化URL
    sentence = re.sub(r'((www\.[\S]+)|(https?://[\S]+))', ' URL ', sentence)
    # 去掉空白，单双引号
    sentence = sentence.strip(' "\'')
    # 分词
    words = jieba.cut(sentence)
    # 分别处理每一个单词
    sentence = []
    for word in words:
        word = preprocess_word(word)
        if len(word) > 0:
            sentence.append(word)
    if len(sentence) == 0:
        return ' '.join(list('很好'))
    else:
        return ' '.join(sentence)

# 38                                   轻薄 皮套 防 摔 防滑 奢华 商务
# 39    促销 优惠 一满 48 减 8 元 满 88 减 20 元 \n 购物 无忧 一 京东 放心...
# 40    手机 壳 任意 2 件 9.5 折 3 件 9 折 + 19.9 元 换购 高清 钢化 膜 ...
# 41                         智能 休眠 翻盖 皮套 免 翻盖 接听电话 智能 省 电
# 42    美国 mil 军工 防 摔 认证 匠心 之作 六个月 质保 品质 保证 嘿 记得 在 店铺 ...
# 43    顺丰 包邮 隔日 到家 凯夫 拉 手机 壳 耐高温 耐酸碱 遇火 阻燃 防 摔 防滑 防 攀...
# 44    关注 下单 送 钢化 膜 下单 请 注意 型号 选购 p20 镜头 膜 请点此 链接 下单 ...
# 45    2 件 8.5 折 京东 仓 发货 新款 液态 超薄 防 摔 软壳 硅胶 手机 壳 防 摔 ...
# 46    时尚 国潮 中国 风 3d 立体 浮雕 软 硅胶 设计 防汗防 指纹 不滑手 高出 摄像头 ...
# 47                                          拍下 即 送 钢化 膜
# 48    秒 变 保时捷 超跑 基因 皮纹 与 有机玻璃 的 相结合 跑车 磁吸 指环 360 度 可...
# 49    正品 保障 终生 免费 换 新 一次 三年 质保 关注 惊喜 关注 店铺 享受 粉丝 专享 ...
# 50                    七夕 大促 来 袭 全店 商品 2 件 7.5 折 买 3 免 1
# 51    火速 发货 6 点前 下单 当天 发货 \n 智能 视窗 屏幕 灵动 随心 知性 优雅 · ...
# 52    关注 送 钢化 膜 30 天价 保 采用 优质 原料 不 发黄 不掉 漆 推荐 配套 全屏 ...
# 53                  关注 下单 送膜 流光 闪镀 全新 升级 真机 实测 镜头 精准 保护
# 54    精选 优质 头层 牛皮 假一罚 十 匠心 工艺 可 360 度 旋转 磁吸 指环 一体 支架...
# 55    在线 支付 免 运费 前盖 内嵌 锰钢 耐 刮 耐磨 耐 摔 晶莹 皮 防水 耐脏 耐用 内...
# 56    现货 速发 真机 开模 下单 送 钢化 贴膜 精美 手机 绳 指环 支架 无 白边 无缝 贴...
# 57    促销 优惠 买 3 免 1 收藏 关注 送 保护膜 软壳 不 伤机 四角 保护 抗震 防 摔...
# 58                           全景 智能 视窗 免 翻盖 接听 下单 送 钢化 膜
# 59    真皮 手工 定制 款 奢华 品质 20 年 直属 工厂 闪电 做货 确保 时效 保证 真皮 ...
# 60    华为 p20 手机 壳 液态 硅胶 p20pro 防 摔 p10 纯色 情侣 p10plus...
# 61    秒 变 保时捷 超跑 基因 头层 牛皮 与 有机玻璃 的 相结合 商务 轻奢 触感 舒适 柔...
# 62    送 钢化 膜 夏天 新款 舒适 而 新颖 独特 的 磨砂 包边 防滑 防汗 握感 更 出众 ...
# 63    关注 商品 下单 即 送 磁吸 指环 + 钢化 膜 边框 硅胶 背面 布纹 舒适 手感 防滑...
# 64    真皮 诠释 精选 头层 牛皮 匠心 之作 商务 轻奢 触感 舒适 柔软 适握 锻造 工艺 孔...
# 65                                          行货 品质 原装 正品
# 66                                          行货 品质 专柜 正品
# Name: name, Length: 67, dtype: object

# %%
from wordcloud import WordCloud

# %%
exp= data["name"]

wc = WordCloud(background_color="white", max_words=5000, 
                max_font_size= 50,
              font_path="/Library/Fonts/Songti.ttc",)

wc.generate(" ".join(str(s) for s in exp.values))

plt.figure(figsize=(20,12))
plt.title('What are the most expensive items', fontsize = 30)
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
